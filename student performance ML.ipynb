# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
c=pd.read_csv('Student_performance_data _.csv')
c
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
c.dtypes
# Out:
# StudentID              int64
# Age                    int64
# Gender                 int64
# Ethnicity              int64
# ParentalEducation      int64
# StudyTimeWeekly      float64
# Absences               int64
# Tutoring               int64
# ParentalSupport        int64
# Extracurricular        int64
# Sports                 int64
# Music                  int64
# Volunteering           int64
# GPA                  float64
# GradeClass           float64
# dtype: object

# %%
c.head(4)
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# 1             0  3.042915         1.0
# 2             0  0.112602         4.0
# 3             0  2.054218         3.0

# %%
c.tail(4)
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
#       Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 2388         4         1                4                0       1      0
# 2389        20         0                2                0       0      0
# 2390        17         0                2                0       1      1
# 2391        13         0                2                0       0      0
#
#       Volunteering       GPA  GradeClass
# 2388             0  3.279150         4.0
# 2389             1  1.142333         2.0
# 2390             0  1.803297         1.0
# 2391             1  2.140014         1.0

# %%
c.isna().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
c.columns
# Out:
# Index(['StudentID', 'Age', 'Gender', 'Ethnicity', 'ParentalEducation',
#        'StudyTimeWeekly', 'Absences', 'Tutoring', 'ParentalSupport',
#        'Extracurricular', 'Sports', 'Music', 'Volunteering', 'GPA',
#        'GradeClass'],
#       dtype='object')

# %%
c.index
# Out:
# RangeIndex(start=0, stop=2392, step=1)

# %%
c.shape
# Out:
# (2392, 15)

# %%
c.size
# Out:
# 35880

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
c.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
c.nunique()
# Out:
# StudentID            2392
# Age                     4
# Gender                  2
# Ethnicity               4
# ParentalEducation       5
# StudyTimeWeekly      2392
# Absences               30
# Tutoring                2
# ParentalSupport         5
# Extracurricular         2
# Sports                  2
# Music                   2
# Volunteering            2
# GPA                  2371
# GradeClass              5
# dtype: int64

# %%
c.count()
# Out:
# StudentID            2392
# Age                  2392
# Gender               2392
# Ethnicity            2392
# ParentalEducation    2392
# StudyTimeWeekly      2392
# Absences             2392
# Tutoring             2392
# ParentalSupport      2392
# Extracurricular      2392
# Sports               2392
# Music                2392
# Volunteering         2392
# GPA                  2392
# GradeClass           2392
# dtype: int64

# %%
c.groupby('Gender')['Age'].mean()
# Out:
# Gender
# 0    16.417094
# 1    16.518003
# Name: Age, dtype: float64

# %%
c.rename({'Extracurricular': 'Extra curicular activity'},axis=1)
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
c.drop_duplicates()
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
c.to_csv('cleaned stud.csv',index=False)

# %%
u=pd.read_csv('cleaned stud.csv')
u
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
plt.figure(figsize=(8, 6))
plt.hist(u['GPA'], bins=15, color='skyblue', edgecolor='black')
plt.title('Distribution of GPA')
plt.xlabel('GPA')
plt.ylabel('Number of Students')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Gender', y='GPA', data=u, palette="Set2")
plt.title('GPA by Gender')
plt.xlabel('Gender (0 = Female, 1 = Male)')
plt.ylabel('GPA')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(u['StudyTimeWeekly'], u['GPA'], color='purple', alpha=0.6)
plt.title('Study Time vs. GPA')
plt.xlabel('Study Time (Hours per Week)')
plt.ylabel('GPA')
plt.show()

# %%
avg=u.groupby('Gender')['GPA'].mean()
plt.figure(figsize=(8, 6))
avg.plot(kind='bar', color=['lightblue', 'lightgreen'], edgecolor='black')
plt.title('Average GPA by Gender')
plt.xlabel('Gender (0 = Female, 1 = Male)')
plt.ylabel('Average GPA')
plt.xticks(rotation=0)
plt.show()

# %%
edu= u.groupby('ParentalEducation')['StudyTimeWeekly'].mean()

plt.figure(figsize=(8, 6))
edu.plot(kind='line', marker='o', color='orange', linewidth=2)
plt.title('Average Study Time by Parental Education Level')
plt.xlabel('Parental Education Level')
plt.ylabel('Average Study Time (Hours per Week)')
plt.grid(True)
plt.show()

# %%
gender_distribution = u['Gender'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(gender_distribution, labels=['Male', 'Female'], autopct='%1.1f%%', colors=['lightblue', 'lightgreen'], startangle=140)
plt.title('Gender Distribution')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='GradeClass', data=u, palette="muted")
plt.title('Count of Students by Grade Class')
plt.xlabel('Grade Class')
plt.ylabel('Number of Students')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x='Gender', y='GPA', data=u, palette="Set3", inner='quartile')
plt.title('Distribution of GPA by Gender')
plt.xlabel('Gender (0 = Female, 1 = Male)')
plt.ylabel('GPA')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(u['GPA'], bins=15, kde=True, color='red')
plt.title('Histogram of GPA')
plt.xlabel('GPA')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.relplot(x='StudyTimeWeekly', y='GPA', hue='Gender', data=u, kind='scatter', palette='Set1', height=6, aspect=1.5)
plt.title('GPA vs. Study Time by Gender')
plt.xlabel('Study Time (Hours per Week)')
plt.ylabel('GPA')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.regplot(x='Absences', y='GPA', data=u,scatter_kws={'alpha':0.6}, line_kws={"color":"black"})
plt.title('GPA vs. Absences with Regression Line')
plt.xlabel('Number of Absences')
plt.ylabel('GPA')
plt.show()

# %%
sns.jointplot(x='StudyTimeWeekly', y='GPA', data=u, kind='reg', height=8, color='grey')
plt.suptitle('Jointplot of GPA and Study Time with Regression', y=1.02)
plt.xlabel('Study Time (Hours per Week)')
plt.ylabel('GPA')
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # decision tree

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.metrics import r2_score,accuracy_score,confusion_matrix,precision_score,classification_report
x=u.iloc[:,:-1]
x
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
y=u['GradeClass']
y
# Out:
# 0       2.0
# 1       1.0
# 2       4.0
# 3       3.0
# 4       4.0
#        ...
# 2387    0.0
# 2388    4.0
# 2389    2.0
# 2390    1.0
# 2391    1.0
# Name: GradeClass, Length: 2392, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
print(x_train,x_test,y_train,y_test)
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 380        1381   18       1          2                  1         3.772645
# 226        1227   15       0          2                  1        11.448155
# 1075       2076   15       1          1                  2        19.570119
# 715        1716   18       1          0                  2        10.071401
# 1822       2823   18       0          1                  1         2.158491
# ...         ...  ...     ...        ...                ...              ...
# 1638       2639   15       0          1                  0        13.092424
# 1095       2096   16       0          0                  2         2.159249
# 1130       2131   16       1          0                  2         3.572578
# 1294       2295   18       0          3                  2         4.402585
# 860        1861   18       0          1                  2         5.427628
#
# ...

# %%
tree_model=DecisionTreeClassifier(criterion='entropy',max_depth=3,random_state=42) 
tree_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=42)

# %%
pred=tree_model.predict(x_test)
pred
# Out:
# array([4., 1., 3., 1., 4., 2., 3., 3., 3., 4., 3., 4., 2., 3., 2., 4., 4.,
#        4., 3., 3., 4., 4., 4., 1., 4., 4., 4., 1., 3., 3., 3., 4., 2., 1.,
#        4., 4., 1., 2., 1., 4., 2., 1., 4., 3., 4., 3., 2., 4., 2., 4., 1.,
#        1., 4., 4., 1., 1., 3., 1., 4., 3., 4., 3., 3., 4., 4., 4., 1., 3.,
#        4., 1., 1., 4., 2., 2., 4., 2., 3., 4., 4., 4., 3., 1., 3., 4., 4.,
#        4., 1., 4., 1., 4., 2., 4., 4., 4., 1., 4., 1., 4., 4., 4., 4., 3.,
#        4., 1., 4., 3., 2., 4., 4., 4., 4., 3., 1., 4., 4., 4., 3., 2., 4.,
#        3., 4., 1., 1., 4., 4., 4., 2., 4., 3., 2., 4., 1., 2., 4., 4., 4.,
#        3., 4., 4., 4., 2., 4., 1., 4., 2., 4., 4., 2., 1., 4., 1., 4., 1.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 3., 1.,
#        4., 1., 1., 4., 4., 2., 3., 4., 3., 4., 2., 4., 4., 2., 2., 2., 1.,
#        1., 4., 4., 4., 3., 4., 4., 4., 4., 4., 3., 2., 3., 4., 1., 1., 3.,
# ...

# %%
dt_accuracy=accuracy_score(y_test,pred)
print(dt_accuracy)
# Out:
# 0.9011142061281338

# %%
cnf=confusion_matrix(y_test,pred)
print(cnf)
# Out:
# [[  0  22   4   3   4]
#  [  0  75   1   2   2]
#  [  0   5 108   5   3]
#  [  0   5   4 113   5]
#  [  0   6   0   3 348]]

# %%
pre=precision_score(y_test,pred,average='macro')
print(pre)
# Out:
# 0.6889890201824882
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        33
#          1.0       0.66      0.94      0.78        80
#          2.0       0.92      0.89      0.91       121
#          3.0       0.90      0.89      0.89       127
#          4.0       0.96      0.97      0.97       357
#
#     accuracy                           0.90       718
#    macro avg       0.69      0.74      0.71       718
# weighted avg       0.87      0.90      0.88       718
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
ne=np.array([[1001,17,1,0,2,19.833723,7,1,2,0,0,1,0,2.929196]])
ps=tree_model.predict(ne)
print(f'GradeClass: {ps[0]:.2f}')
# Out:
# GradeClass: 2.00
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
plt.figure(figsize=(40,20))
plot_tree(tree_model,
          filled=True,
          feature_names=x.columns,
          class_names=[str(cls) for cls in tree_model.classes_],
          rounded=True)
plt.title("decision Tree visualisation")
plt.show()

# %% [markdown]
# # random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
x=c.iloc[:,:-1]
x
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
y=c['GradeClass']
y
# Out:
# 0       2.0
# 1       1.0
# 2       4.0
# 3       3.0
# 4       4.0
#        ...
# 2387    0.0
# 2388    4.0
# 2389    2.0
# 2390    1.0
# 2391    1.0
# Name: GradeClass, Length: 2392, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
print(x_train,x_test,y_train,y_test)
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 380        1381   18       1          2                  1         3.772645
# 226        1227   15       0          2                  1        11.448155
# 1075       2076   15       1          1                  2        19.570119
# 715        1716   18       1          0                  2        10.071401
# 1822       2823   18       0          1                  1         2.158491
# ...         ...  ...     ...        ...                ...              ...
# 1638       2639   15       0          1                  0        13.092424
# 1095       2096   16       0          0                  2         2.159249
# 1130       2131   16       1          0                  2         3.572578
# 1294       2295   18       0          3                  2         4.402585
# 860        1861   18       0          1                  2         5.427628
#
# ...

# %%
tree_model=RandomForestClassifier(n_estimators=10,criterion='entropy',random_state=42) #how many decision trees
tree_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=42)

# %%
pred=tree_model.predict(x_test)
pred
# Out:
# array([4., 1., 0., 0., 4., 2., 3., 3., 3., 4., 2., 4., 2., 2., 2., 4., 4.,
#        4., 3., 3., 4., 4., 4., 1., 4., 4., 4., 2., 3., 3., 3., 4., 2., 1.,
#        4., 4., 1., 2., 1., 4., 2., 0., 4., 3., 4., 3., 2., 4., 0., 4., 1.,
#        1., 4., 4., 3., 1., 3., 1., 4., 3., 4., 3., 3., 4., 4., 3., 1., 2.,
#        4., 1., 0., 4., 2., 2., 4., 2., 3., 4., 4., 4., 3., 1., 3., 4., 4.,
#        4., 0., 4., 4., 4., 2., 4., 4., 4., 1., 4., 1., 4., 4., 4., 4., 3.,
#        4., 1., 4., 3., 2., 4., 4., 4., 4., 3., 1., 4., 4., 4., 3., 1., 4.,
#        3., 4., 1., 1., 4., 4., 4., 2., 4., 3., 2., 4., 0., 2., 4., 4., 4.,
#        3., 4., 4., 4., 2., 4., 1., 4., 2., 4., 4., 2., 1., 4., 1., 4., 1.,
#        4., 4., 4., 4., 4., 4., 2., 4., 4., 4., 4., 4., 4., 4., 4., 3., 1.,
#        4., 1., 1., 4., 4., 2., 3., 4., 3., 4., 2., 4., 4., 2., 2., 2., 1.,
#        0., 4., 4., 4., 3., 4., 4., 4., 4., 4., 3., 2., 3., 4., 1., 3., 3.,
# ...

# %%
rf_accuracy=accuracy_score(y_test,pred)
print(rf_accuracy)
# Out:
# 0.9011142061281338

# %%
cnf=confusion_matrix(y_test,pred)
print(cnf)
# Out:
# [[ 15   9   2   2   5]
#  [  3  70   5   0   2]
#  [  1   7 105   5   3]
#  [  2   4   8 110   3]
#  [  0   2   0   8 347]]

# %%
pre=precision_score(y_test,pred,average='macro')
print(pre)
# Out:
# 0.8388088336783989

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.45      0.56        33
#          1.0       0.76      0.88      0.81        80
#          2.0       0.88      0.87      0.87       121
#          3.0       0.88      0.87      0.87       127
#          4.0       0.96      0.97      0.97       357
#
#     accuracy                           0.90       718
#    macro avg       0.84      0.81      0.82       718
# weighted avg       0.90      0.90      0.90       718

# %%
ne=np.array([[1001,17,1,0,2,19.833723,7,1,2,0,0,1,0,2.929196]])
ps=tree_model.predict(ne)
print(f'GradeClass: {ps[0]:.2f}')
# Out:
# GradeClass: 2.00
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # svm

# %%
from sklearn.preprocessing import StandrdScaler
from sklearn.svm import SVC

# %%
x=c.iloc[:,:-1]
x
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
y=c['GradeClass']
y
# Out:
# 0       2.0
# 1       1.0
# 2       4.0
# 3       3.0
# 4       4.0
#        ...
# 2387    0.0
# 2388    4.0
# 2389    2.0
# 2390    1.0
# 2391    1.0
# Name: GradeClass, Length: 2392, dtype: float64

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.3,random_state=42)
print(x_train,x_test,y_train,y_test)
# Out:
# [[-1.18100966  1.36294441  0.97849211 ... -0.49516139  2.31553495
#    0.67645163]
#  [-1.40403295 -1.30713178 -1.02198065 ... -0.49516139 -0.43186565
#   -1.11951878]
#  [-0.17450848 -1.30713178  0.97849211 ... -0.49516139 -0.43186565
#    0.20816014]
#  ...
#  [-0.09485731 -0.41710638  0.97849211 ... -0.49516139 -0.43186565
#    0.15927692]
#  [ 0.14264801  1.36294441 -1.02198065 ... -0.49516139 -0.43186565
#   -0.60897322]
#  [-0.48587215  1.36294441 -1.02198065 ... -0.49516139 -0.43186565
#   -2.07015988]] [[-0.2773309  -1.30713178  0.97849211 ...  2.01954358  2.31553495
#   -0.52292949]
#  [-1.44747904 -0.41710638  0.97849211 ... -0.49516139  2.31553495
#    1.32373237]
#  [ 1.6603649  -1.30713178 -1.02198065 ... -0.49516139  2.31553495
#    0.14381134]
#  ...
#  [-0.35263747 -1.30713178  0.97849211 ... -0.49516139 -0.43186565
#   -0.79378259]
#  [-0.59159098  1.36294441 -1.02198065 ... -0.49516139  2.31553495
#    0.79692168]
# ...

# %%
model=SVC(kernel='linear')
model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([4., 2., 4., 1., 4., 2., 4., 3., 3., 4., 3., 4., 1., 3., 2., 4., 4.,
#        4., 3., 3., 4., 4., 4., 1., 4., 4., 4., 1., 3., 3., 3., 4., 2., 1.,
#        4., 4., 1., 1., 1., 4., 2., 1., 4., 3., 4., 3., 2., 4., 2., 4., 1.,
#        1., 4., 4., 4., 1., 3., 1., 4., 3., 4., 3., 2., 4., 4., 4., 1., 3.,
#        4., 1., 1., 4., 1., 2., 4., 2., 3., 4., 4., 4., 4., 1., 3., 4., 4.,
#        4., 1., 4., 4., 4., 3., 4., 4., 4., 4., 4., 1., 4., 4., 4., 4., 3.,
#        4., 4., 4., 3., 2., 4., 4., 4., 4., 3., 1., 4., 4., 4., 4., 1., 4.,
#        3., 4., 1., 1., 4., 4., 4., 2., 4., 3., 2., 4., 1., 2., 4., 4., 4.,
#        3., 4., 4., 4., 2., 4., 1., 4., 2., 4., 4., 2., 1., 4., 1., 4., 1.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 2., 1.,
#        4., 1., 1., 4., 4., 2., 3., 4., 3., 4., 2., 4., 4., 2., 2., 2., 1.,
#        4., 4., 4., 4., 3., 4., 4., 4., 4., 4., 3., 2., 3., 4., 1., 4., 3.,
# ...

# %%
s_accuracy=accuracy_score(y_test,y_pred)
print(s_accuracy)
# Out:
# 0.8467966573816156

# %%
cnf=confusion_matrix(y_test,y_pred)
print(cnf)
# Out:
# [[  0  23   2   3   5]
#  [  0  62  11   1   6]
#  [  0   9  99   7   6]
#  [  0   3  11 101  12]
#  [  0   2   1   8 346]]

# %%
pre=precision_score(y_test,y_pred,average='macro')
print(pre)
# Out:
# 0.6377966112740306
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        33
#          1.0       0.63      0.78      0.69        80
#          2.0       0.80      0.82      0.81       121
#          3.0       0.84      0.80      0.82       127
#          4.0       0.92      0.97      0.95       357
#
#     accuracy                           0.85       718
#    macro avg       0.64      0.67      0.65       718
# weighted avg       0.81      0.85      0.83       718
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
ne=np.array([[1001,17,1,0,2,19.833723,7,1,2,0,0,1,0,2.929196]])
ps=tree_model.predict(ne)
print(f'GradeClass: {ps[0]:.2f}')
# Out:
# GradeClass: 2.00
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
models = ['Random Forest', 'SVC', 'Decision Tree']
accuracies = [rf_accuracy,s_accuracy, dt_accuracy]
plt.figure(figsize=(8, 6))
plt.bar(models, accuracies, color=['skyblue', 'grey', 'brown'])
plt.title('Model Comparison: Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Models')
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
k=3

# %%
kmeans=KMeans(n_clusters=k,random_state=0) #n_clusters- no of clusters you want to genrate
kmeans.fit(x)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3, random_state=0)

# %%
label=kmeans.labels_ 
u['cluster']=label     
u['cluster']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2387    0
# 2388    0
# 2389    0
# 2390    0
# 2391    0
# Name: cluster, Length: 2392, dtype: int32

# %%
u
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
plt.figure(figsize=(10,6))
colors=plt.get_cmap('viridis',k)
for cluster in range(k):  
    cd=u[u['cluster']==cluster]
    plt.scatter(cd['Age'],cd['Gender'],color=colors(cluster),label=f'cluster {cluster + 1}')
centroids=kmeans.cluster_centers_ 
plt.scatter(centroids[:,0],centroids[:,1],color='black',marker='x',s=100,label='centroids')
plt.xlabel('Age')
plt.ylabel('Gender')
plt.title('clusters of age and gender')
plt.legend()
plt.show()
